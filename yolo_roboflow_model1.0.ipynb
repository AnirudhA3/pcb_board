# %% [markdown]
# <a href="https://colab.research.google.com/github/AnirudhA3/pcb_board/blob/main/yolo_roboflow_model1.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U ultralytics opencv-python-headless matplotlib tqdm

# %%
from ultralytics import YOLO
import torch

print("YOLOv8 version:", YOLO.__module__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# YOLOv8 version: ultralytics.models.yolo.model
# CUDA available: True

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # or yolov8s.pt if you have GPU memory

# Note: use the correct absolute path to your uploaded file
model.train(
    data="/mnt/data/data.yaml",  # ✅ points to your actual file
    epochs=100,
    imgsz=640,
    batch=16,
    name="pcb_yolov8",
    project="runs/train"
)
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xmXScffvNLtGuxtdUfN4")
project = rf.workspace("roboflow-100").project("printed-circuit-board")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="xmXScffvNLtGuxtdUfN4")  # 👈 replace this!
project = rf.workspace("roboflow-100").project("printed-circuit-board")
dataset = project.version(4).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !ls -R /content
# Out:
# /content:
# data.yaml		 README.dataset.txt   runs	   yolov8n.pt
# printed-circuit-board-4  README.roboflow.txt  sample_data
#
# /content/printed-circuit-board-4:
# roboflow.zip
#
# /content/runs:
# detect	train
#
# /content/runs/detect:
# pcb_yolov8
#
# /content/runs/detect/pcb_yolov8:
# args.yaml  weights
#
# /content/runs/detect/pcb_yolov8/weights:
#
# /content/runs/train:
# pcb_yolov8  pcb_yolov82  pcb_yolov83  pcb_yolov84
#
# /content/runs/train/pcb_yolov8:
# args.yaml  weights
#
# /content/runs/train/pcb_yolov8/weights:
#
# /content/runs/train/pcb_yolov82:
# args.yaml  weights
#
# /content/runs/train/pcb_yolov82/weights:
#
# /content/runs/train/pcb_yolov83:
# args.yaml  weights
#
# /content/runs/train/pcb_yolov83/weights:
#
# /content/runs/train/pcb_yolov84:
# args.yaml  weights
#
# /content/runs/train/pcb_yolov84/weights:
#
# /content/sample_data:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# ...

# %%
# !ls -R /content/printed-circuit-board-4
# Out:
# /content/printed-circuit-board-4:
# roboflow.zip

# %%
# !unzip -q /content/printed-circuit-board-4/roboflow.zip -d /content/printed-circuit-board-4/
# Out:
# [/content/printed-circuit-board-4/roboflow.zip]
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/printed-circuit-board-4/roboflow.zip or
#         /content/printed-circuit-board-4/roboflow.zip.zip, and cannot find /content/printed-circuit-board-4/roboflow.zip.ZIP, period.

# %%
# !ls -R /content/printed-circuit-board-4 | head -n 40
# Out:
# /content/printed-circuit-board-4:
# roboflow.zip

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="xmXScffvNLtGuxtdUfN4")  # 👈 put your actual key here
project = rf.workspace("roboflow-100").project("printed-circuit-board")
dataset = project.version(4).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
curl -L "https://universe.roboflow.com/ds/XXXXXXXXXX?key=YYYYYYYYYY" -o printed-circuit-board.zip
# Out:
#   File "/tmp/ipython-input-3233750226.py", line 1
#     curl -L "https://universe.roboflow.com/ds/XXXXXXXXXX?key=YYYYYYYYYY" -o printed-circuit-board.zip
#             ^
# SyntaxError: invalid syntax

# %%
# !ls -R "/content/drive/My Drive/YOLO" | head -n 80
# Out:
# /content/drive/My Drive/YOLO:
# board images
# data.zip.zip
# my_model
# my_model.zip
#
# /content/drive/My Drive/YOLO/board images:
#
# /content/drive/My Drive/YOLO/my_model:
# my_model.pt
# train
# yolo_detect.py
#
# /content/drive/My Drive/YOLO/my_model/train:
# args.yaml
# BoxF1_curve.png
# BoxP_curve.png
# BoxPR_curve.png
# BoxR_curve.png
# confusion_matrix_normalized.png
# confusion_matrix.png
# labels.jpg
# results.csv
# weights
#
# /content/drive/My Drive/YOLO/my_model/train/weights:
# best.pt
# last.pt

# %%
# Unzip (allow overwriting)
# !unzip -o "/content/drive/My Drive/YOLO/data.zip.zip" -d "/content/drive/My Drive/YOLO/pcb_dataset" || true

# List what's inside after extraction
# !ls -R "/content/drive/My Drive/YOLO/pcb_dataset" | head -n 200
# Out:
# Archive:  /content/drive/My Drive/YOLO/data.zip.zip
#    creating: /content/drive/My Drive/YOLO/pcb_dataset/images/
#    creating: /content/drive/My Drive/YOLO/pcb_dataset/labels/
#   inflating: /content/drive/My Drive/YOLO/pcb_dataset/classes.txt
#   inflating: /content/drive/My Drive/YOLO/pcb_dataset/notes.json
#   inflating: /content/drive/My Drive/YOLO/pcb_dataset/images/001bed22-IMG-20250929-WA0083.jpg
#   inflating: /content/drive/My Drive/YOLO/pcb_dataset/images/0264dc12-IMG-20250929-WA0037.jpg
#   inflating: /content/drive/My Drive/YOLO/pcb_dataset/images/02b6c123-IMG-20250929-WA0073.jpg
#   inflating: /content/drive/My Drive/YOLO/pcb_dataset/images/070be5e1-IMG-20250929-WA0018.jpg
#   inflating: /content/drive/My Drive/YOLO/pcb_dataset/images/0ba0c933-IMG-20250929-WA0029.jpg
#   inflating: /content/drive/My Drive/YOLO/pcb_dataset/images/0e606406-IMG-20250929-WA0058.jpg
#   inflating: /content/drive/My Drive/YOLO/pcb_dataset/images/12670379-IMG-20250929-WA0008.jpg
# ...

# %%
import os, random, shutil
from pathlib import Path

base = Path("/content/drive/My Drive/YOLO/pcb_dataset")
images = list((base / "images").glob("*.jpg"))
random.shuffle(images)

split_ratio = 0.8
train_count = int(len(images) * split_ratio)

train_imgs = images[:train_count]
val_imgs = images[train_count:]

def move_files(file_list, subset):
    (base / subset / "images").mkdir(parents=True, exist_ok=True)
    (base / subset / "labels").mkdir(parents=True, exist_ok=True)
    for img_path in file_list:
        label_path = base / "labels" / (img_path.stem + ".txt")
        if label_path.exists():
            shutil.copy(img_path, base / subset / "images" / img_path.name)
            shutil.copy(label_path, base / subset / "labels" / label_path.name)

move_files(train_imgs, "train")
move_files(val_imgs, "valid")

print(f"✅ Split complete: {len(train_imgs)} train, {len(val_imgs)} valid images.")
# Out:
# ✅ Split complete: 66 train, 17 valid images.

# %%
classes_path = "/content/drive/My Drive/YOLO/pcb_dataset/classes.txt"
yaml_path = "/content/drive/My Drive/YOLO/pcb_dataset/data.yaml"

# Read class names
with open(classes_path, "r") as f:
    class_names = [line.strip() for line in f if line.strip()]

print(f"Classes detected ({len(class_names)}): {class_names}")

# Write YAML file properly
with open(yaml_path, "w") as f:
    f.write("path: /content/drive/My Drive/YOLO/pcb_dataset\n")
    f.write("train: train/images\n")
    f.write("val: valid/images\n")
    f.write(f"nc: {len(class_names)}\n")
    f.write(f"names: {class_names}\n")

print(f"\n✅ data.yaml created successfully at: {yaml_path}")
# Out:
# Classes detected (2): ['Capacitor', 'Resistor']
#
# ✅ data.yaml created successfully at: /content/drive/My Drive/YOLO/pcb_dataset/data.yaml

# %%
from ultralytics import YOLO

# Load base model (you can switch to 'yolov8s.pt' or 'yolov8m.pt' for higher accuracy)
model = YOLO("yolov8n.pt")

# Train on your dataset
model.train(
    data="/content/drive/My Drive/YOLO/pcb_dataset/data.yaml",
    epochs=100,                     # You can adjust (50–150 typical)
    imgsz=640,                      # Image size (increase to 1024 for finer components)
    batch=8,                        # Adjust depending on GPU memory
    name="pcb_yolov8_cap_res",      # Run name
    project="/content/drive/My Drive/YOLO/runs"  # Save everything in Drive
)
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics.data.utils import check_det_dataset
check_det_dataset("/content/drive/My Drive/YOLO/pcb_dataset/data.yaml")
# Out:
# {'path': PosixPath('/content/drive/My Drive/YOLO/pcb_dataset'),
#  'train': '/content/drive/My Drive/YOLO/pcb_dataset/train/images',
#  'val': '/content/drive/My Drive/YOLO/pcb_dataset/valid/images',
#  'nc': 2,
#  'names': {0: 'Capacitor', 1: 'Resistor'},
#  'yaml_file': '/content/drive/My Drive/YOLO/pcb_dataset/data.yaml',
#  'channels': 3}

# %%
# !echo "🔍 Searching for YOLO runs..."
# !find /content -type d -name "runs" 2>/dev/null | head -n 20

# !echo -e "\n🔍 Searching for best.pt files..."
# !find /content -type f -name "best.pt" 2>/dev/null | head -n 20
# Out:
# 🔍 Searching for YOLO runs...
# /content/drive/MyDrive/YOLO/runs
# /content/drive/.Encrypted/MyDrive/YOLO/runs
# /content/runs
#
# 🔍 Searching for best.pt files...
# /content/drive/MyDrive/YOLO/my_model/train/weights/best.pt
# /content/drive/MyDrive/YOLO/runs/pcb_yolov8_cap_res/weights/best.pt

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO("/content/drive/MyDrive/YOLO/runs/pcb_yolov8_cap_res/weights/best.pt")

# Run prediction on validation images
results = model.predict(
    source="/content/drive/My Drive/YOLO/pcb_dataset/valid/images",
    conf=0.25,
    save=True,
    project="/content/drive/MyDrive/YOLO/predictions",
    name="pcb_detect"
)

print("✅ Inference complete! Check saved results in:")
print("/content/drive/MyDrive/YOLO/predictions/pcb_detect")
# Out:
# image 1/17 /content/drive/My Drive/YOLO/pcb_dataset/valid/images/0e606406-IMG-20250929-WA0058.jpg: 640x480 4 Capacitors, 1 Resistor, 39.9ms
# image 2/17 /content/drive/My Drive/YOLO/pcb_dataset/valid/images/2f4a0dcd-IMG-20250929-WA0085.jpg: 640x480 4 Capacitors, 1 Resistor, 6.2ms
# image 3/17 /content/drive/My Drive/YOLO/pcb_dataset/valid/images/3a22fc08-IMG-20250929-WA0013.jpg: 480x640 3 Capacitors, 1 Resistor, 45.2ms
# image 4/17 /content/drive/My Drive/YOLO/pcb_dataset/valid/images/5284a4aa-IMG-20250929-WA0043.jpg: 640x480 3 Capacitors, 1 Resistor, 7.5ms
# image 5/17 /content/drive/My Drive/YOLO/pcb_dataset/valid/images/61526f3c-IMG-20250929-WA0055.jpg: 640x480 3 Capacitors, 1 Resistor, 6.2ms
# image 6/17 /content/drive/My Drive/YOLO/pcb_dataset/valid/images/66d30cc9-IMG-20250929-WA0020.jpg: 640x480 3 Capacitors, 1 Resistor, 6.4ms
# image 7/17 /content/drive/My Drive/YOLO/pcb_dataset/valid/images/719eeed6-IMG-20250929-WA0075.jpg: 640x480 3 Capacitors, 1 Resistor, 6.1ms
# ...

# %%
# ==============================================================
# PCB COMPARISON — YOLOv8 | JSON Diff | Red Box Visualization
# ==============================================================

# 🧰 Requirements
# !pip install -q ultralytics opencv-python Pillow matplotlib numpy

# ==============================================================
# 🧠 Imports
# ==============================================================
import os, cv2, json
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO
from google.colab import files

# ==============================================================
# 🔧 Setup
# ==============================================================
OUT_DIR = "/content/pcb_output"
os.makedirs(OUT_DIR, exist_ok=True)

# 👇 Path to your trained YOLOv8 model
MODEL_PATH = "/content/drive/MyDrive/YOLO/runs/pcb_yolov8_cap_res/weights/best.pt"

model = YOLO(MODEL_PATH)
print("✅ YOLOv8 model loaded successfully from:", MODEL_PATH)

# ==============================================================
# 🧩 Utility Functions
# ==============================================================
def auto_crop_board(image):
    """Auto-crops the PCB area using green color segmentation."""
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    lower_green = np.array([25, 30, 30])
    upper_green = np.array([100, 255, 255])
    mask = cv2.inRange(hsv, lower_green, upper_green)
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if not contours:
        return image
    x, y, w, h = cv2.boundingRect(max(contours, key=cv2.contourArea))
    return image[y:y+h, x:x+w]

def detect_with_yolo(image, prefix="B"):
    """Runs YOLO detection on a PCB image and returns annotated image + JSON."""
    results = model(image)
    annotated = results[0].plot()  # image with boxes
    comps = []
    for i, box in enumerate(results[0].boxes):
        cls_id = int(box.cls)
        label = results[0].names[cls_id]
        x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
        comps.append({
            "id": f"{prefix}{i}",
            "label": label,
            "position": [int(x1), int(y1), int(x2 - x1), int(y2 - y1)]
        })
    return annotated, comps

def compare_json(master, test):
    """Compares master and test JSONs for missing or moved components."""
    diffs = []
    for m in master["components"]:
        match = next((t for t in test["components"] if t["label"] == m["label"]), None)
        if not match:
            diffs.append({"label": m["label"], "status": "missing in test", "old_position": m["position"]})
        else:
            dx = abs(m["position"][0] - match["position"][0])
            dy = abs(m["position"][1] - match["position"][1])
            if dx > 10 or dy > 10:
                diffs.append({
                    "label": m["label"], "status": "moved",
                    "old_position": m["position"],
                    "new_position": match["position"]
                })
    return {"differences": diffs}

def visualize_differences(diff_json, test_img):
    """Draws red boxes on moved/missing components."""
    for d in diff_json["differences"]:
        if d["status"] == "missing in test":
            x, y, w, h = d["old_position"]
            cv2.rectangle(test_img, (x,y), (x+w,y+h), (0,0,255), 2)
            cv2.putText(test_img, f"{d['label']} missing", (x, y-5),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 1)
        elif d["status"] == "moved":
            nx, ny, nw, nh = d["new_position"]
            cv2.rectangle(test_img, (nx,ny), (nx+nw,ny+nh), (0,0,255), 2)
            cv2.putText(test_img, f"{d['label']} moved", (nx,ny-5),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 1)
    return test_img

# ==============================================================
# 📤 Upload PCB Images
# ==============================================================
print("📸 Upload your MASTER and TEST PCB images")
uploaded = files.upload()
paths = list(uploaded.keys())
if len(paths) < 2:
    raise ValueError("Please upload both master and test PCB images.")

master_img = cv2.imread(paths[0])
test_img   = cv2.imread(paths[1])

# ==============================================================
# 🔍 YOLO Detection + JSON Save
# ==============================================================
master_crop = auto_crop_board(master_img)
test_crop   = auto_crop_board(test_img)

master_detected, master_comps = detect_with_yolo(master_crop, "M")
test_detected, test_comps = detect_with_yolo(test_crop, "T")

master_json = {"components": master_comps}
test_json   = {"components": test_comps}

cv2.imwrite(f"{OUT_DIR}/master_detected.png", master_detected)
cv2.imwrite(f"{OUT_DIR}/test_detected.png", test_detected)
with open(f"{OUT_DIR}/master.json", "w") as f: json.dump(master_json, f, indent=2)
with open(f"{OUT_DIR}/test.json", "w") as f: json.dump(test_json, f, indent=2)

print("✅ YOLO detection complete. JSON files saved to:", OUT_DIR)

# ==============================================================
# 🔁 Compare JSONs + Visualize Differences
# ==============================================================
diff_json = compare_json(master_json, test_json)
with open(f"{OUT_DIR}/differences.json", "w") as f: json.dump(diff_json, f, indent=2)

visualized = visualize_differences(diff_json, test_detected.copy())
cv2.imwrite(f"{OUT_DIR}/difference_visual.png", visualized)

plt.imshow(cv2.cvtColor(visualized, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

print("🟥 Visual comparison saved at:", f"{OUT_DIR}/difference_visual.png")
# Out:
# ✅ YOLOv8 model loaded successfully from: /content/drive/MyDrive/YOLO/runs/pcb_yolov8_cap_res/weights/best.pt
# 📸 Upload your MASTER and TEST PCB images
#      <input type="file" id="files-e3a543e6-78c1-4ac9-b88c-512769043ef8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3a543e6-78c1-4ac9-b88c-512769043ef8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# ...
